# %%
a= 2
print(type(a))
# Out:
# <class 'int'>

# %%
# float
b=2.4
print(type(b))
# Out:
# <class 'float'>

# %%
#string
c='AI'
print(type(c))
# Out:
# <class 'str'>

# %%
z=True
print(type(z))
# Out:
# <class 'bool'>

# %% [markdown]
# Arithmetic Opeartion

# %%
#Addition
a=1
b=2
sum=a+b
print(sum)
# Out:
# 3

# %%
#subtractation
c=5
d=3
diff=a-b
print(diff)
# Out:
# -1

# %%
#mode= it give remeidner
a%b
# Out:
# 1

# %%
a*b
# Out:
# 2

# %%
a//b
# Out:
# 0

# %% [markdown]
# BOOLEAN

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True or False
# Out:
# False

# %%
not False or True
# Out:
# True

# %%
True and not False
# Out:
# True

# %% [markdown]
# String formating

# %%
firstname="Sushma"
lastname="Poudel"
address="Butwal"

# %%
print("My firstname and lastname is", firstname,lastname)
# Out:
# My firstname and lastname is Sushma Poudel

# %%
print("My fisrtname is {} and lastname is {}". format(firstname, lastname))
# Out:
# My fisrtname is Sushma and lastname is Poudel

# %%
print("My lastname is {} and firstname is {}". format(lastname, firstname))
# Out:
# My lastname is Poudel and firstname is Sushma

# %%
print ("My firstname is {b} and lastname is {a}".format (a=firstname,b=lastname))
# Out:
# My firstname is Poudel and lastname is Sushma

# %%
print( "My fisrtname is {} and lastname is {} and My address is {}.". format(firstname, lastname, address))
# Out:
# My fisrtname is Sushma and lastname is Poudel and My address is Butwal.

# %%
print (f'My firstname is {firstname} and lastname is {lastname} and my address is {address}')
# Out:
# My firstname is Sushma and lastname is Poudel and my address is Butwal
