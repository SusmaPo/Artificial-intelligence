# %% [markdown]
# Environmnet setup
# 1. install pandas
# 2. install numpy
# 3. install matplotlib
# 4. install scikit-learn

# %% [markdown]
# Exercise 1. Answer the quiz available via canvas.

# %% [markdown]
# Exercise 2: Install the required libraries and its dependences

# %% [markdown]
# Exercise 3: Cortez,Paulo. (2014). Student Performance. UCI Machine Learning Repository.
# https://doi.org/10.24432/C5TG7T.

# %% [markdown]
# Exercise 4: you can open the file using MS excel to check its content

# %% [markdown]
# Exercise 5

# %%
#  install necessary libraries
import pandas as pd

# %%
file_name = 'student-mat.csv'

# %%
df = pd. read_csv(file_name, sep =';')

display(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Exercise 6

# %%
# Display basic information about the dataset
print("Shape of the DataFrame:")
print(df.shape)

print("\nColumns in the DataFrame:")
print(df.columns)
# Out:
# Shape of the DataFrame:
# (395, 33)
#
# Columns in the DataFrame:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# Exercise 7

# %%
# Display summary statistics of numerical columns
print("\nSummary Statistics:")
display(df.describe())
# Out:
# Summary Statistics:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# Exercise 8

# %%
# Check for any missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Exercise 9

# %%
#  Check for any duplicate rows 
print("\nDuplicate Rows:") 
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 0

# %% [markdown]
# Exercise 10

# %%
print("\nData types of the columns:")
print(df.dtypes)
# Out:
# Data types of the columns:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Exercise 11

# %%
import matplotlib.pyplot as plt 
 
# Selecting only numerical columns 
numerical_columns = df.select_dtypes(include=['int64', 'float64']) 
 
# Calculating correlations 
correlations = numerical_columns.corr() 
 
# Creating a basic heatmap to visualize the correlations 
plt.figure(figsize=(10, 8)) 
plt.imshow(correlations, cmap='coolwarm', interpolation='nearest') 
plt.colorbar() 
plt.xticks(range(len(correlations)), correlations.columns, rotation=90) 
plt.yticks(range(len(correlations)), correlations.columns) 
plt.title('Correlation Heatmap of Student Performance Dataset') 
plt.show()

# %% [markdown]
# Exericse 12

# %%
# Generate value counts for categorical variables
print("\nValue Counts for Categorical Variables:")
print(df['sex'].value_counts())
print(df['address'].value_counts())
# Out:
# Value Counts for Categorical Variables:
# sex
# F    208
# M    187
# Name: count, dtype: int64
# address
# U    307
# R     88
# Name: count, dtype: int64

# %% [markdown]
# Exercise 13

# %%
import matplotlib.pyplot as plt

# Example: Histogram of AGE
plt.figure(figsize=(8, 6))
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Exercise 14

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from  sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
# Selecting the features and target variables
X= df[['G1']] # Feature Variable
y= df['G3'] #Target variable

# %%
#  Splitting the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
random_state=0)

# %%
#  Creating and fitting the model 
model = LinearRegression() 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#  Predicting the target values 
y_pred = model.predict(X_test)

# %% [markdown]
# Exercise 15:

# %%
#  Calculating Mean Absolute Error 
mae = mean_absolute_error(y_test, y_pred) 
print("Mean Absolute Error:", mae) 
 
# Calculating Mean Squared Error 
mse = mean_squared_error(y_test, y_pred) 
print("Mean Squared Error:", mse) 
 
# Calculating R-squared 
r2 = r2_score(y_test, y_pred) 
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 2.0107180614189373
# Mean Squared Error: 8.38800753657445
# R-squared: 0.6959638345717838

# %% [markdown]
# Exercise 16:

# %%
# Plotting the data points and the regression line 
plt.scatter(X_test, y_test, color='black', label='Actual data') 
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Regression line') 
plt.title('Single Variable Linear Regression') 
plt.xlabel('First Test Grade (G1)') 
plt.ylabel('Final Grade (G3)') 
plt.legend() 
plt.show()

# %% [markdown]
# Exercise 17:  Try 3 different independent variables and compare the results. Write a comment
# on the best variable for the prediction (make sure that the variable you are testing is a numeric
# one as we cannot use a string as a number).

# %%
# List of numeric variables to test
variables = ['G1', 'G2', 'studytime']

results = {}

for var in variables:
    print(f"\nTesting variable: {var}")

    X = df[[var]]
    y = df['G3']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    model = LinearRegression()
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    results[var] = (mae, mse, r2)

    print("MAE:", mae)
    print("MSE:", mse)
    print("R² :", r2)
# Out:
# Testing variable: G1
# MAE: 2.0107180614189373
# MSE: 8.38800753657445
# R² : 0.6959638345717838
#
# Testing variable: G2
# MAE: 1.3260063744973654
# MSE: 5.63653417115305
# R² : 0.7956951960009399
#
# Testing variable: studytime
# MAE: 4.233414392839641
# MSE: 28.61380053882542
# R² : -0.0371509749149701

# %% [markdown]
# Exercise 18

# %%
# Feature variables
X = df[['G1', 'G2', 'age', 'traveltime', 'studytime', 'failures']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Feature 1
X = df[['G1']]
y = df['G3']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("Using G1:")
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))
# Out:
# Using G1:
# MAE: 2.0107180614189373
# MSE: 8.38800753657445
# R²: 0.6959638345717838

# %% [markdown]
# Exercise 19
#
# Car Price Prediction

# %%
import pandas as pd

file_name = 'car_price.csv'

# %%
df = pd.read_csv(file_name)
display(df.head())
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#  Display basic information about the dataset 
print("Shape of the DataFrame:") 
print(df.shape) 
print("\nColumns in the DataFrame:") 
print(df.columns)
# Out:
# Shape of the DataFrame:
# (205, 26)
#
# Columns in the DataFrame:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
#  Display summary statistics of numerical columns 
print("\nSummary Statistics:") 
display(df.describe())
# Out:
# Summary Statistics:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
#  Check for any missing values 
print("\nMissing Values:") 
print(df.isnull().sum())
# Out:
# Missing Values:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
#  Check for any duplicate rows 
print("\nDuplicate Rows:") 
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 0

# %%
print("\nData types of the columns:")
print(df.dtypes)
# Out:
# Data types of the columns:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
import matplotlib.pyplot as plt 
 
# Selecting only numerical columns 
numerical_columns = df.select_dtypes(include=['int64', 'float64']) 
 
# Calculating correlations 
correlations = numerical_columns.corr() 
 
# Creating a basic heatmap to visualize the correlations 
plt.figure(figsize=(10, 8)) 
plt.imshow(correlations, cmap='coolwarm', interpolation='nearest') 
plt.colorbar() 
plt.xticks(range(len(correlations)), correlations.columns, rotation=90) 
plt.yticks(range(len(correlations)), correlations.columns) 
plt.title('Correlation Heatmap of Student Performance Dataset') 
plt.show()

# %%
print("\nValue Counts for Categorical Variables:") 
print(df['fueltype'].value_counts())
print(df['carbody'].value_counts())
# Out:
# Value Counts for Categorical Variables:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt 
 
plt.figure(figsize=(8,6))
plt.hist(df['price'], bins=20,  color='skyblue', edgecolor='black')
plt.xlabel('Car Price')
plt.ylabel('Frequency')
plt.title('Histogram of Car Prices')
plt.show()

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score 
import matplotlib.pyplot as plt

# %%
#  Selecting the feature and target variables 
X = df[['enginesize']]
y = df['price']

# %%
#  Splitting the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
random_state=0)

# %%
# Creating and fitting the model 
model = LinearRegression() 
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#  Predicting the target values 
y_pred = model.predict(X_test)

# %%
#  Calculating Mean Absolute Error 
mae = mean_absolute_error(y_test, y_pred) 
print("Mean Absolute Error:", mae) 
 
# Calculating Mean Squared Error 
mse = mean_squared_error(y_test, y_pred) 
print("Mean Squared Error:", mse) 
 
# Calculating R-squared 
r2 = r2_score(y_test, y_pred) 
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 3195.0312395000433
# Mean Squared Error: 16835544.038137678
# R-squared: 0.7825324721447275

# %%
 
# Plotting the data points and the regression line 
plt.scatter(X_test, y_test, label='Actual Data')
plt.plot(X_test, y_pred, linewidth=3, label='Regression Line')
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.title('Single Variable Linear Regression')
plt.legend()
plt.show()

# %%
# List of numeric variables to test
variables = ['enginesize', 'horsepower', 'curbweight']

results = {}

for var in variables:
    print(f"\nTesting variable: {var}")

    X = df[[var]]
    y = df['price']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    model = LinearRegression()
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    results[var] = (mae, mse, r2)

    print("MAE:", mae)
    print("MSE:", mse)
    print("R² :", r2)
# Out:
# Testing variable: enginesize
# MAE: 3195.0312395000433
# MSE: 16835544.038137678
# R² : 0.7825324721447275
#
# Testing variable: horsepower
# MAE: 3733.693369050242
# MSE: 29626244.651337314
# R² : 0.6173128608515996
#
# Testing variable: curbweight
# MAE: 3256.3206615301897
# MSE: 25249391.104349032
# R² : 0.6738494074872148

# %% [markdown]
# Commnent: Based on the results, enginesize is the best single predictor of car price because it has the lowest MAE/MSE and the highest R² value (0.78) compared to horsepower and curbweight.

# %%
# MULTIPLE FEATURES selected from correlation matrix
X = df[['enginesize', 'horsepower', 'curbweight', 'carwidth']]
y = df['price']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

# Model training
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Evaluation metrics
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
# Out:
# MAE: 2870.41685448597
# MSE: 15586017.18288619
# R-squared: 0.7986728187581045
