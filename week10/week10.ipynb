# %% [markdown]
#  # Exercise 1

# %%
#  installing the requied libraries

# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# !pip install tensorflow
# !pip install opencv-python
# Out:
# Requirement already satisfied: pandas in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (2.2.6)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (74.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.10.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.10.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.10.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.7)
# Requirement already satisfied: pillow in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\sushm\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.2.6)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Exercise 2

# %% [markdown]
# Download image

# %% [markdown]
# # Exercise 3

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image_path = 'Image_1.jpeg'
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.title('colour Image')
plt.show()

# %% [markdown]
# # Exercise 4

# %%
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap='gray')
plt.title('Grey Scaled Image')
plt.show()

# %% [markdown]
# # Exercise 5

# %%
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap='gray')
plt.title('Grey Scaled Image')
plt.savefig('grey_scale.jpeg')
plt.show()

# %% [markdown]
# # Exercise 6

# %%
print(image.shape)
# Out:
# (1600, 2560)

# %% [markdown]
# # Exercise 7

# %%
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
image = image[50:100,100:150]
plt.imshow(image, cmap='gray')
plt.title('Grey Scaled Image')
plt.show()

# %% [markdown]
# # Exercise 8

# %%
# Calculate histogram using OpenCV
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
hist = cv2.calcHist([image], [0], None, [256], [0, 256])
plt.plot(hist)
plt.title('Image Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Exercise 9

# %%
import keras
from tensorflow.keras.utils import load_img 

# load the image
img = load_img(image_path)

# find more about the image
print(type(img))
print(img.format)
print(img.mode)
print(img.size)

# show the image
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (2560, 1600)

# %% [markdown]
# # Exercise 10

# %% [markdown]
#
# What are Convolutional Neural Networks? | IBM

# %% [markdown]
# # Exercise 11

# %%
from keras.models import Sequential 
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense 
from keras.utils import to_categorical 
from keras.datasets import mnist

# %% [markdown]
# # Exercise 12

# %%
# Load the MNIST dataset 
(X_train, y_train), (X_test, y_test) = mnist.load_data() 
 
# Reshape the images and normalize pixel values to be between 0 and 1 
X_train = X_train.reshape(-1, 28, 28, 1).astype('float64') / 255.0 
X_test = X_test.reshape(-1, 28, 28, 1).astype('float64') / 255.0

# %% [markdown]
# # Exercise 13

# %%
# Display images and corresponding class names 
class_names = [str(i) for i in range(10)]
num_rows, num_cols = 2, 5  # Display 2 rows and 5 columns of images 
plt.figure(figsize=(12, 6)) 
 
for i in range(num_rows * num_cols): 
    plt.subplot(num_rows, num_cols, i + 1) 
    plt.imshow(X_train[i], cmap='gray') 
    plt.title(f'Class: {class_names[y_train[i]]}') 
    plt.axis('off') 
 
plt.show()

# %% [markdown]
# # Exercise 14

# %%
# One-hot encode the labels 
y_train = to_categorical(y_train, 10) 
y_test = to_categorical(y_test, 10)

# %% [markdown]
# # Exercise 15

# %%
# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy',
metrics=['accuracy'])
# Out:
# c:\Users\sushm\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Exercise 16

# %%
# Train the model 
model.fit(X_train, y_train, epochs=5, batch_size=64, validation_data=(X_test, 
y_test))
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.9439 - loss: 0.1844 - val_accuracy: 0.9765 - val_loss: 0.0717
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9844 - loss: 0.0516 - val_accuracy: 0.9883 - val_loss: 0.0336
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9884 - loss: 0.0376 - val_accuracy: 0.9862 - val_loss: 0.0441
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9910 - loss: 0.0273 - val_accuracy: 0.9912 - val_loss: 0.0290
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9930 - loss: 0.0222 - val_accuracy: 0.9862 - val_loss: 0.0415

# %% [markdown]
# # Exercise 17

# %%
# Evaluate the model 
loss, accuracy = model.evaluate(X_test, y_test) 
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9862 - loss: 0.0415
# Test Accuracy: 98.62%

# %% [markdown]
# # Exercise 18

# %%
# Predictions on the test set
predictions = model.predict(X_test)
# Find indices of correctly and incorrectly classified images
correct_indices = np.where(np.argmax(predictions, axis=1) == np.argmax(y_test,
axis=1))[0]

incorrect_indices = np.where(np.argmax(predictions, axis=1) !=
np.argmax(y_test, axis=1))[0]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
# Display examples of corretly classified images
plt.figure(figsize=(12, 6))
plt.suptitle('Correclty Classified Images', fontsize=16)

for i in range(5):
    plt.subplot(2, 5, i+1)
    plt.imshow(X_test[correct_indices[i]].reshape(28, 28), cmap='gray')
    plt.title(f'Predicted:{np.argmax(predictions[correct_indices[i]])}\nActual: {np.argmax(y_test[correct_indices[i]])}')
    plt.axis('off')

# Display examples of misclassified images
plt.figure(figsize=(12, 6))
plt.suptitle('Misclassified Images', fontsize=16)

for i in range(5):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[incorrect_indices[i]].reshape(28, 28), cmap='gray')
    plt.title(f'Predicted :{np.argmax(predictions[incorrect_indices[i]])}\nActual ;{np.argmax(y_test[incorrect_indices[i]])}')
    plt.axis('off')

plt.show()

# %% [markdown]
# # Exercise 19

# %% [markdown]
# Answer the quiz available via canvas
